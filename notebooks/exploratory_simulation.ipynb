# %% [markdown]
# # Exploratory simulation
#
# This notebook demonstrates the queue survival model with synthetic data.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT / 'src'))

from queue_model import TruncatedWeibullDiningTime, predict_entry_time
from queue_model.plotting import plot_waiting_time_distribution

dist = TruncatedWeibullDiningTime(shape=3, scale=95, max_time=120)
result = predict_entry_time(120, 20, 40, dist, n_simulations=5000, random_state=42)
result['mean_wait'], result['median_wait'], result['q90_wait']

# %%
plot_waiting_time_distribution(result['waiting_time_samples']);
